# %%
import sys
sys.path.insert(0, '..')

import importlib
import src.preprocessing.load_data

importlib.reload(src.preprocessing.load_data)

from src.preprocessing.load_data import load_stage1_data

df = load_stage1_data()

print(df.head())
# Out:
# Raw dataset shape: (706, 109)
# After column selection: (706, 24)
#             District Names                   State/UT  \
# 0                 Nicobars  Andaman & Nicobar Islands
# 1  North & Middle Andaman   Andaman & Nicobar Islands
# 2           South Andaman   Andaman & Nicobar Islands
# 3              Srikakulam              Andhra Pradesh
# 4            Vizianagaram              Andhra Pradesh
#
#    Population living in households with electricity (%)  \
# 0                                               97.9
# 1                                               93.2
# 2                                               99.6
# 3                                               99.9
# 4                                               99.5
#
#    Population living in households with an improved drinking-water source1 (%)  \
# 0                                               98.8
# 1                                               92.2
# 2                                               97.9
# ...

# %%
import src.preprocessing.clean

print(dir(src.preprocessing.clean))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'handle_missing', 'np', 'pd']
